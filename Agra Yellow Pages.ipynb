# %%
import urllib3
import csv
import re
from bs4 import BeautifulSoup
import requests
 
rank_page = 'https://socialblade.com/youtube/top/50/mostviewed'
req = urllib3.PoolManager()
request = req.request('GET', rank_page)
# page = urllib3.urlopen(request)
soup = BeautifulSoup(page, 'html.parser')

r = requests.get('https://socialblade.com/youtube/top/50/mostviewed')

soup = BeautifulSoup(r.text, 'html.parser')
 
channels = soup.find('div', attrs={'style': 'float: right; width: 900px;'})
 
file = open('topyoutubers.csv', 'w')
writer = csv.writer(file)
 
# write title row
writer.writerow(['Username', 'Uploads', 'Views'])
 
print(channels)
# for channel in channels:
#     username = channel.find('div', attrs={'style': 'float: left; width: 350px; line-height: 25px;'}).a.text.strip()
#     uploads = channel.find('div', attrs={'style': 'float: left; width: 80px;'}).span.text.strip()
#     views = channel.find_all('div', attrs={'style': 'float: left; width: 150px;'})[1].span.text.strip()
 
#     print(username + ' ' + uploads + ' ' + views)
#     writer.writerow([username.encode('utf-8'), uploads.encode('utf-8'), views.encode('utf-8')])
 
file.close()
# Out:
# None

# %%
pip install urllib2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Could not find a version that satisfies the requirement urllib2 (from versions: )
# No matching distribution found for urllib2

# %%
import csv
import re
from bs4 import BeautifulSoup
import requests
 
# rank_page = 'https://socialblade.com/youtube/top/50/mostviewed'
# request = urllib.request(rank_page)
# page = urllib.urlopen(request)
# soup = BeautifulSoup(page, 'html.parser')
 
# channels = soup.find('div', attrs={'style': 'float: right; width: 900px;'}).find_all('div', recursive=False)[4:]
 
file = open('topyoutubers.csv', 'wb')
writer = csv.writer(file)
 
# write title row
writer.writerow([Username, Uploads, Views])
 
# for channel in channels:
#     username = channel.find('div', attrs={'style': 'float: left; width: 350px; line-height: 25px;'}).a.text.strip()
#     uploads = channel.find('div', attrs={'style': 'float: left; width: 80px;'}).span.text.strip()
#     views = channel.find_all('div', attrs={'style': 'float: left; width: 150px;'})[1].span.text.strip()
 
#     print(username + ' ' + uploads + ' ' + views)
#     writer.writerow([username.encode('utf-8'), uploads.encode('utf-8'), views.encode('utf-8')])
 
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7e212c244230> in <module>
#      15
#      16 # write title row
# ---> 17 writer.writerow(Username, Uploads, Views)
#      18
#      19 # for channel in channels:
#
# NameError: name 'Username' is not defined

# %%
import xlsxwriter
workbook = xlsxwriter.Workbook('c:\\Users\\mahes\\Desktop\\Welocme.xlsx')
worksheet = workbook.add_worksheet()
worksheet.write('A1', 'Name of the student')
worksheet.write('B1', 'Subject')

row = 1
col = 0
 
data = ( 
    ['Rajendra', 'IT'], 
    ['Kashish','Physiotherapist'], 
    ['Arun', 'Student'], 
    ['Rohan','Bank Manager'], 
) 
 
for name, score in (data): 
    worksheet.write(row, col, name) 
    worksheet.write(row, col + 1, score) 
    row += 1
workbook.close()

# %%
import requests
from bs4 import BeautifulSoup
import os
import pandas as pd
import numpy as np

# filename = 'atta.csv'
# f=open(filename, 'w', newline ='')
# atta = csv.writer(f)

url = ('https://www.jiomart.com/c/groceries/staples/atta-flours-sooji/26')

def scraping_images(url, folder):
    try: 
        os.mkdir(os.path.join(os.getcwd(), folder))
    except: 
        pass
    os.chdir(os.path.join(os.getcwd(), folder))
    r = requests.get(url)

    soup = BeautifulSoup(r.text, 'html.parser')

    images = soup.find_all('img')
    image_link = []
    
    for image in images:
        link = image['src']
        image_link.append(link)
    return image_link  
    

def imagedown(url, folder):
    try: 
        os.mkdir(os.path.join(os.getcwd(), folder))
    except: 
        pass
    os.chdir(os.path.join(os.getcwd(), folder))
    r = requests.get(url)

    soup = BeautifulSoup(r.text, 'html.parser')

    products = soup.find_all('div', class_="row product-list")
    
    for product in products:
        product_name = product.find_all('span', class_='clsgetname')
        product_discount = product.find_all('span', class_='dis_section')
        
        x = list(zip(product_name,product_discount))

        outer_list = []  
        for y in x:
            inner_list = []
            for z in y:
                inner_list.append(z.text)
            outer_list.append(inner_list)
        
            
        main_list = list(zip(outer_list))
        print(main_list)
#         for i in main_list:
#             print(i)

        
imagedown('https://www.jiomart.com/c/groceries/staples/atta-flours-sooji/26', 'Atta Price')
# Out:
# [(['Atta Dal Rice Combo - Chakki Atta 5 kg + Toor Dal 2 kg + Surti Kolam Rice 2 kg', ' 21% OFF '],), (['Aashirvaad Whole Wheat Atta 1 kg', ' 7% OFF '],), (['Broken Wheat / Daliya 500 g', ' 50% OFF '],), (['Broken Wheat / Daliya 1 kg', ' 50% OFF '],), (['Good Life MP Wheat Chakki Atta 1 kg', ' 22% OFF '],), (['Fortune Chakki Fresh Whole Wheat Atta 10 kg', ' 14% OFF '],), (['Nature Fresh Sampoorna Chakki Whole Wheat Atta 10 kg', ' 23% OFF '],), (['Uttam Rawa / Sooji 1 kg', ' 18% OFF '],), (['Madam Rawa 500 g', ' 7% OFF '],), (["Uttam Wheat's Daliya 500 g", ' 12% OFF '],), (['Besan 1 kg', ' 53% OFF '],), (['Besan 500 g', ' 53% OFF '],), (['Madam Rice Atta / Flour 500 g', ' 7% OFF '],), (['Gaay Chhap Maraiyo / Varai 500 g', ' 7% OFF '],), (['Rawa 500 g', ' 53% OFF '],), (['Manna Diabetic Multigrain Atta 1 kg', ' 10% OFF '],), (['Manna Plain Ragi Flour 500 g', ' 10% OFF '],), (['Manna Rice Flour 500 g', ' 10% OFF '],), (['Manna Rice Flour 1 kg', ' 10% OFF '],), (['Aashirvaad Whole Wheat A
# ...

# %%
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-846c1dbd158b> in <module>
# ----> 1 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
pip install urllib2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Could not find a version that satisfies the requirement urllib2 (from versions: )
# No matching distribution found for urllib2

# %%
import requests
from bs4 import BeautifulSoup
import os
import xlsxwriter
from itertools import chain
import itertools


# import xlsxwriter
# workbook = xlsxwriter.Workbook('c:\\Users\\mahes\\Desktop\\Welocme.xlsx')
# worksheet = workbook.add_worksheet()
# worksheet.write('A1', 'Name of the student')
# worksheet.write('B1', 'Mobile Number')

# row = 1
# col = 0
 
# data = ( 
#     ['Rajendra', 'IT'], 
#     ['Kashish','Physiotherapist'], 
#     ['Arun', 'Student'], 
#     ['Rohan','Bank Manager'], 
# ) 
 
data = ()


# for name, score in (data): 
#     worksheet.write(row, col, name) 
#     worksheet.write(row, col + 1, score) 
#     row += 1
# workbook.close()


def getData(url):

    r = requests.get(url)

    soup = BeautifulSoup(r.text, 'html.parser')

    images = soup.find_all('h2')
    first = []
    second = []
    for i in images:
#         print(i)
        first = first.append(i.text)
    
    image = soup.find_all('span', class_='t_2')
    
    for j in image:
#         print(i)
        second = second.append(i.text)
    
    print(first, second)
    
getData('http://www.agrayellowpages.in/agricultural-cf-agents.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d63e65231685> in <module>
#      56
#      57
# ---> 58 getData('http://www.agrayellowpages.in/agricultural-cf-agents.html')
#
# <ipython-input-19-d63e65231685> in getData(url)
#      44     for i in images:
#      45 #         print(i)
# ---> 46         first = first.append(i.text)
#      47
#      48     image = soup.find_all('span', class_='t_2')
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
import requests
from bs4 import BeautifulSoup
import os
import xlsxwriter
from itertools import chain
import itertools


import xlsxwriter
workbook = xlsxwriter.Workbook('c:\\Users\\mahes\\Desktop\\Welocme.xlsx')
worksheet = workbook.add_worksheet()
worksheet.write('A1', 'Name of the student')
worksheet.write('B1', 'Mobile Number')

row = 1
col = 0
 
data = ( 
    ['Rajendra', 'IT'], 
    ['Kashish','Physiotherapist'], 
    ['Arun', 'Student'], 
    ['Rohan','Bank Manager'], 
) 
 
data = ()


# for name, score in (data): 
#     worksheet.write(row, col, name) 
#     worksheet.write(row, col + 1, score) 
#     row += 1
# workbook.close()


def getData(url):

    r = requests.get(url)

    soup = BeautifulSoup(r.text, 'html.parser')
    
    first = soup.find_all('td')

    dat = []
    for i in first:
        dat.append(i.text)
#         print(i.text.strip())
#     print(dat)
    
    for i in dat:
        print(i.strip())
#             j.strip()
#             if(j.find('Mobile') == 0):
#                print(j + "mahiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii")
        
        
        

    second = soup.find_all('div', class_='t_1')

    data = []
    secfinal = []
    for i in second:
        data.append(i.text.strip())
#         print(i.text.strip())
#     print(data)
    
    for i in data:
        if(i.find('Mobile') == 0):
            print(i[8:22])
#            secfinal.append(i[8:22])
        
        

        
getData('http://www.agrayellowpages.in/agricultural-cf-agents.html')
# Out:
# Gopal Trading Co
# Deals in Agriculture Hardware, Spare Parts, Tools, Agriculture Machinery, Agriculture Equipments.Street Address :21/62, FreeGanj, Agra-282001, Uttar Pradesh, IndiaPhone :+91-562-2267059City :Agra
# Website : http://www.agrayellowpages.in/Gopal-Trading-Co.htm
# View Details
# Send Inquiry
#
# Chaudhary Agro Field
# Deals in Agriculture Machinery, Agriculture Equipments & spare partsStreet Address :Rohta Ka Bagh, Gwalior Road, Agra-282001, Uttar Pradesh, IndiaCity :Agra
# Website : http://www.agrayellowpages.in/Chaudhary-Agro-Field.htm
# View Details
# Send Inquiry
#
# Nand Kishor Lalaram & Co
# Deals in Agriculture Equipments, Machines & spare partsStreet Address :4/63, Opposite DIG Kothi, BaluGanj, Agra-282001, Uttar Pradesh, IndiaPhone :+91-562-2363021City :Agra
# Website : http://www.agrayellowpages.in/Nand-Kishor-Lalaram-and-Co.htm
# View Details
# Send Inquiry
#
# Shyamji Pumps
# ...

# %%
import requests
from bs4 import BeautifulSoup
import os
import xlsxwriter
from itertools import chain
import itertools

def getData(url):

    r = requests.get(url)

    soup = BeautifulSoup(r.text, 'html.parser')

    second = soup.find_all('div', class_='t_1')

    data = []
    secfinal = []
    for i in second:
        data.append(i.text.strip())
#         print(i.text.strip())
#     print(data)
    
    workbook = xlsxwriter.Workbook("C:\\Users\\mahes\\Desktop\\try.xlsx")
    worksheet1 = workbook.add_worksheet()
    
    for i in data:
        if((i.find('Mobile') == 0) and (i[8:12] == "+91-")):
#             print(i[8:22])
            secfinal.append(i[8:22])
    
    from itertools import chain

    list1 = list(chain(*secfinal))
    
    print(list1)

    for row_num, data in enumerate(secfinal):
        worksheet1.write(row_num, 0, data)
        
    workbook.close()
        
    return(secfinal)
        
        
def getMobile(url):
    
    if(url == 'http://www.agrayellowpages.in/agricultural-inputs-fertilizers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/agricultural-inputs-fertilizers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=agricultural-inputs-fertilizers&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)      
    
    else:
        getData(url)
        
getMobile('http://www.agrayellowpages.in/agricultural-inputs-fertilizers.html')
# Out:
# ['+', '9', '1', '-', '9', '3', '5', '9', '3', '5', '4', '1', '8', '1', '+', '9', '1', '-', '9', '4', '1', '1', '0', '0', '1', '1', '2', '7', '+', '9', '1', '-', '9', '7', '5', '8', '8', '2', '6', '5', '0', '6', '+', '9', '1', '-', '9', '5', '6', '8', '3', '4', '2', '5', '5', '4', '+', '9', '1', '-', '5', '6', '2', '-', '2', '3', '6', '6', '9', '9', '+', '9', '1', '-', '9', '3', '6', '8', '6', '0', '3', '5', '3', '3', '+', '9', '1', '-', '9', '3', '6', '8', '6', '0', '3', '5', '3', '3', '+', '9', '1', '-', '9', '8', '9', '7', '6', '2', '5', '4', '6', '6', '+', '9', '1', '-', '9', '4', '1', '0', '0', '0', '4', '3', '2', '0', '+', '9', '1', '-', '9', '4', '1', '2', '2', '5', '8', '4', '5', '2', '+', '9', '1', '-', '9', '3', '1', '9', '8', '1', '8', '7', '3', '2']

# %%
import requests
from bs4 import BeautifulSoup
import os
import xlsxwriter
from itertools import chain
import itertools

def getData(url):

    r = requests.get(url)

    soup = BeautifulSoup(r.text, 'html.parser')

    second = soup.find_all('div', class_='t_1')

    data = []
    secfinal = []
    for i in second:
        data.append(i.text.strip())
#         print(i.text.strip())
#     print(data)
    
    for i in data:
        if((i.find('Mobile') == 0) and (i[8:12] == "+91-")):
#             print(i[8:22])
           secfinal.append(i[8:22])
    return(secfinal)
        
        
def getMobile(url):
    
    if(url == 'http://www.agrayellowpages.in/agricultural-inputs-fertilizers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/agricultural-inputs-fertilizers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=agricultural-inputs-fertilizers&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/food-products.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/food-products.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=food-products&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/agricultural-equipment-implements.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/agricultural-equipment-implements.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=agricultural-equipment-implements&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/agricultural-pipes.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/agricultural-pipes.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=agricultural-pipes&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/dairy-products.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/dairy-products.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=dairy-products&page=2'))
        print(x)
        
#  Agriculture
        
    elif(url == 'http://www.agrayellowpages.in/bangles-shop-mfrs-distributor.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/bangles-shop-mfrs-distributor.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=bangles-shop-mfrs-distributor&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/exporters-leather-goods-shoes.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/exporters-leather-goods-shoes.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=exporters-leather-goods-shoes&page=2'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=exporters-leather-goods-shoes&page=3'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/boutiques.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/boutiques.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=boutiques&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/leather-goods-accessories.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/leather-goods-accessories.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=leather-goods-accessories&page=2'))
        print(x)
        
#  Apperals and garments

    elif(url == 'http://www.agrayellowpages.in/automobiles-accessories.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/automobiles-accessories.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobiles-accessories&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/automobile-car-gas-converters-cng-lpg.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/automobile-car-gas-converters-cng-lpg.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobile-car-gas-converters-cng-lpg&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/automobiles-manufactures-dealers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/automobiles-manufactures-dealers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobiles-manufactures-dealers&page=2'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobiles-manufactures-dealers&page=3'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/automobiles-garages-service-centre.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/automobiles-garages-service-centre.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobiles-garages-service-centre&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/automobiles-gas-kit.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/automobiles-gas-kit.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobiles-gas-kit&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/automobiles-used-cars.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/automobiles-used-cars.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobiles-used-cars&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/ball-roller-bearing-bushes.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/ball-roller-bearing-bushes.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=ball-roller-bearing-bushes&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/battery-storage.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/battery-storage.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=battery-storage&page=2'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=battery-storage&page=3'))

        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/automobiles-manufactures-dealers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/automobiles-manufactures-dealers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobiles-manufactures-dealers&page=2'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=automobiles-manufactures-dealers&page=3'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/diesel-engines-manfacturer-dealers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/diesel-engines-manfacturer-dealers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=diesel-engines-manfacturer-dealers&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/diesel-engines-spares-manufacturers-dealers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/diesel-engines-spares-manufacturers-dealers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=diesel-engines-spares-manufacturers-dealers&page=2'))
        print(x)
        
#   Automobiles

    elif(url == 'http://www.agrayellowpages.in/ayurvedic-medicines.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/ayurvedic-medicines.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=ayurvedic-medicines&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/beauty-saloons-beauticians.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/beauty-saloons-beauticians.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=beauty-saloons-beauticians&page=2'))
        print(x)
        
#   Aurvedic and Herbal
        
    elif(url == 'http://www.agrayellowpages.in/bicycle-manufacturers-dealers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/bicycle-manufacturers-dealers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=bicycle-manufacturers-dealers&page=2'))
        print(x)
        
#   Bicyles & Rickshaw

    elif(url == 'http://www.agrayellowpages.in/business-services.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/business-services.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=business-services&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/interior-decorators-designers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/interior-decorators-designers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=interior-decorators-designers&page=2'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=interior-decorators-designers&page=3'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/share-brokers-consultants-otc-exchanges.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/share-brokers-consultants-otc-exchanges.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=share-brokers-consultants-otc-exchanges&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/tax-practitioners-agents-consultants.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/tax-practitioners-agents-consultants.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
            
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)
    
 
    else:
        getData(url)
        
getMobile('http://www.agrayellowpages.in/food-products.html')
# Out:
# [['+91-9928011115', '+91-9828552618', '+91-9486446909', '+91-9412280839', '+91-9922951162', '+91-9756718463', '+91-9756200515', '+91-9610045555', '+91-9001610666', '+91-9001610666', '+91-9970848060', '+91-9557931339', '+91-7669701410'], ['+91-9319737362', '+91-9720105338', '+91-9837055498', '+91-9557470810', '+91-9411463987']]

# %%
import requests
from bs4 import BeautifulSoup
import os
import xlsxwriter
from itertools import chain
import itertools

def getData(url):

    r = requests.get(url)

    soup = BeautifulSoup(r.text, 'html.parser')

    second = soup.find_all('div', class_='t_1')

    data = []
    secfinal = []
    for i in second:
        data.append(i.text.strip())
    
    for i in data:
        if((i.find('Mobile') == 0) and (i[8:12] == "+91-")):
#             print(i[8:22])
            secfinal.append(i[8:22])
   
    return(secfinal)


        
def getMobile(url):
    workbook = xlsxwriter.Workbook("C:\\Users\\mahes\\Desktop\\try.xlsx")
    worksheet1 = workbook.add_worksheet()
    
    if(url == 'http://www.agrayellowpages.in/agricultural-inputs-fertilizers.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/agricultural-inputs-fertilizers.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=agricultural-inputs-fertilizers&page=2'))
        from functools import reduce
        single_list = reduce(lambda x,y: x+y, x)
        print(single_list)
        for row_num, data in enumerate(single_list):
            worksheet1.write(row_num, 0, data)
            
        
    elif(url == 'http://www.agrayellowpages.in/biotechnology.html'):
        x = []
        x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
        x.append(getData('http://www.agrayellowpages.in/listing/?id=biotechnology&page=2'))
        print(x)      
    
    else:
        x = []
        x.append(getData(url))
        from functools import reduce
        single_list = reduce(lambda x,y: x+y, x)
        
        for row_num, data in enumerate(single_list):
            worksheet1.write(row_num, 0, data)
        
    workbook.close()
    
getMobile('http://www.agrayellowpages.in/doctors-physiotherapists.html')

# getMobile('http://www.agrayellowpages.in/agricultural-cf-agents.html')

# %%
pip install flatten
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Could not find a version that satisfies the requirement flatten (from versions: )
# No matching distribution found for flatten

# %%
import requests
from bs4 import BeautifulSoup
import os
import xlsxwriter
from itertools import chain
import itertools

def getData(url):

    r = requests.get(url)

    soup = BeautifulSoup(r.text, 'html.parser')

    second = soup.find_all('div', class_='t_1')

    data = []
    secfinal = []
    for i in second:
        data.append(i.text.strip())
    
    for i in data:
        if((i.find('Mobile') == 0) and (i[8:12] == "+91-")):
#             print(i[8:22])
            secfinal.append(i[8:22])
   
    return(secfinal)


        
def getMobile():
    workbook = xlsxwriter.Workbook("C:\\Users\\mahes\\Desktop\\1-538.xlsx")
    worksheet1 = workbook.add_worksheet()
    
    
    x = []
    x.append(getData('http://www.agrayellowpages.in/doctors-physiotherapists.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-graphics-dtp-jobwork.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-raw-materials.html'))
    x.append(getData('http://www.agrayellowpages.in/call-centre-training-institute.html'))
    x.append(getData('http://www.agrayellowpages.in/plant-tissue-culture.html'))
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-sports-injury.html'))
    x.append(getData('http://www.agrayellowpages.in/furniture-general.html'))
    x.append(getData('http://www.agrayellowpages.in/pig-iron-cast-iron.html'))
#     2 to 10
    x.append(getData('http://www.agrayellowpages.in/crockery-cutlery.html'))
    x.append(getData('http://www.agrayellowpages.in/clubs-cultural-associations.html'))
    x.append(getData('http://www.agrayellowpages.in/coaching-classes-general-institute.html'))
    x.append(getData('http://www.agrayellowpages.in/tele-communication-systems-equp-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/ice-cream-frozen-desserts.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-manufacturer-dealers.html'))
    x.append(getData('http://www.agrayellowpages.in/dairy-equipments-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/adhesive-glues-gum-products.html'))
    x.append(getData('http://www.agrayellowpages.in/insurance-companies-agents-surveyors-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/school.html'))
#     11 to 20
    x.append(getData('http://www.agrayellowpages.in/elevator-contractors-suppliers-maintainence.html'))
    x.append(getData('http://www.agrayellowpages.in/food-processing-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
    x.append(getData('http://www.agrayellowpages.in/health-club-equipments.html'))
    x.append(getData('http://www.agrayellowpages.in/plywood-timber-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
    x.append(getData('http://www.agrayellowpages.in/machinery-parts-manufacturers-general.html'))
    x.append(getData('http://www.agrayellowpages.in/landscape-environment-horticulturist.html'))
    x.append(getData('http://www.agrayellowpages.in/tax-practitioners-agents-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-neonatologist.html'))
#     21 to 30
    x.append(getData('http://www.agrayellowpages.in/ups.html'))
    x.append(getData('http://www.agrayellowpages.in/copper-chain.html'))
    x.append(getData('http://www.agrayellowpages.in/advertisers-agencies.html'))
    x.append(getData('http://www.agrayellowpages.in/uniforms.html'))
    x.append(getData('http://www.agrayellowpages.in/bangles-shop-mfrs-distributor.html'))
    x.append(getData('http://www.agrayellowpages.in/nut-bolt.html'))
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/shoe-materials.html'))
    x.append(getData('http://www.agrayellowpages.in/glass-products-glassware.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-ENT.html'))
#     31 to 40
    x.append(getData('http://www.agrayellowpages.in/thread-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/tin-products.html'))
    x.append(getData('http://www.agrayellowpages.in/astrologers-palmists.html'))
    x.append(getData('http://www.agrayellowpages.in/beauty-saloons-beauticians.html'))
    x.append(getData('http://www.agrayellowpages.in/wire-wire-products.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-graphics-dtp-jobwork.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-homoeopathic-medicine-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/weighing-measuring-instruments.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-retailer-showroom.html'))
    x.append(getData('http://www.agrayellowpages.in/watches-clocks-manufacturers-retailers.html'))
#     41 to 50
    x.append(getData('http://www.agrayellowpages.in/transport-services.html'))
    x.append(getData('http://www.agrayellowpages.in/printers-offset.html'))
    x.append(getData('http://www.agrayellowpages.in/business-services.html'))
    x.append(getData('http://www.agrayellowpages.in/travel-agents.html'))
    x.append(getData('http://www.agrayellowpages.in/transformers.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-anesthetists.html'))
    x.append(getData('http://www.agrayellowpages.in/industrial-tools.html'))
    x.append(getData('http://www.agrayellowpages.in/magician.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-products.html'))
    x.append(getData('http://www.agrayellowpages.in/paper-manufacturers-distributors-merchants.html'))
#     51 to 60
    x.append(getData('http://www.agrayellowpages.in/insurance-companies-agents-surveyors-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/machine-tools-manufacturers-distributors.html'))
    x.append(getData('http://www.agrayellowpages.in/pipes-tubes-fitting-plastics-pvc.html'))
    x.append(getData('http://www.agrayellowpages.in/educational-institute.html'))
    x.append(getData('http://www.agrayellowpages.in/pest-control-services.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-ultrasonologist.html'))
    x.append(getData('http://www.agrayellowpages.in/invertors.html'))
    x.append(getData('http://www.agrayellowpages.in/vastu-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/hardware-products.html'))
    x.append(getData('http://www.agrayellowpages.in/shoe-components.html'))
#     61 to 70
    x.append(getData('http://www.agrayellowpages.in/mobile-phones.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-endocrinologists.html'))
    x.append(getData('http://www.agrayellowpages.in/water-treatments.html'))
    x.append(getData('http://www.agrayellowpages.in/paper-manufacturers-distributors-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/bangles-shop-mfrs-distributor.html'))
    x.append(getData('http://www.agrayellowpages.in/generators-spares-parts-suppliers-repairs.html'))
    x.append(getData('http://www.agrayellowpages.in/sports-wear.html'))
    x.append(getData('http://www.agrayellowpages.in/oil-processing-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/CCTV.html'))
    x.append(getData('http://www.agrayellowpages.in/Doctors-Dentists.html'))
#     71 to 80
    x.append(getData('http://www.agrayellowpages.in/lubricating-oils-greases.html'))
    x.append(getData('http://www.agrayellowpages.in/food-processing-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/generators-dealers-hirers.html'))
    x.append(getData('http://www.agrayellowpages.in/beauty-saloons-beauticians.html'))
    x.append(getData('http://www.agrayellowpages.in/ayurvedic-medicines.html'))
    x.append(getData('http://www.agrayellowpages.in/glass-products-glassware.html'))
    x.append(getData('http://www.agrayellowpages.in/furniture-general.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-ayurvedic.html'))
    x.append(getData('http://www.agrayellowpages.in/submersible-pump.html'))
    x.append(getData('http://www.agrayellowpages.in/automobile-car-gas-converters-cng-lpg.html'))
#     81 to 90
    x.append(getData('http://www.agrayellowpages.in/tailors-trimmings-drapers-supplies.html'))
    x.append(getData('http://www.agrayellowpages.in/printers-screen.html'))
    x.append(getData('http://www.agrayellowpages.in/food-products.html'))
    x.append(getData('http://www.agrayellowpages.in/salt-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/weighing-measuring-instruments.html'))
    x.append(getData('http://www.agrayellowpages.in/events-management.html'))
    x.append(getData('http://www.agrayellowpages.in/share-brokers-consultants-otc-exchanges.html'))
    x.append(getData('http://www.agrayellowpages.in/photocopying-machines-sale-service.html'))
    x.append(getData('http://www.agrayellowpages.in/glass-products-glassware.html'))
    x.append(getData('http://www.agrayellowpages.in/cleaning-products.html'))
#     91 to 100
    x.append(getData('http://www.agrayellowpages.in/aluminium-utensils-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/health-club-equipments.html'))
    x.append(getData('http://www.agrayellowpages.in/sports-goods-shoes.html'))
    x.append(getData('http://www.agrayellowpages.in/sports-goods-shoes.html'))
    x.append(getData('http://www.agrayellowpages.in/rubber-rubber-product-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-retailer-showroom.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-granules.html'))
    x.append(getData('http://www.agrayellowpages.in/adhesive-glues-gum-products.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-medicine.html'))
    x.append(getData('http://www.agrayellowpages.in/beauty-saloons-beauticians.html'))
#     101 to 110
    x.append(getData('http://www.agrayellowpages.in/electric-contractors.html'))
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/travel-agents.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-semen.html'))
    x.append(getData('http://www.agrayellowpages.in/sheet-metal-products.html'))
    x.append(getData('http://www.agrayellowpages.in/fax-machines-services.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-homoeopathic-medicine-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/chemicals-industrial-general.html'))
    x.append(getData('http://www.agrayellowpages.in/greeting-cards-calenders-galleries.html'))
    x.append(getData('http://www.agrayellowpages.in/petha-namkeen.html'))
#     111 to 120
    x.append(getData('http://www.agrayellowpages.in/Doctors%20Neuro-Surgeon.html'))
    x.append(getData('http://www.agrayellowpages.in/party-place.html'))
    x.append(getData('http://www.agrayellowpages.in/cement-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/agricultural-cf-agents.html'))
    x.append(getData('http://www.agrayellowpages.in/diesel-engines-spares-manufacturers-dealers.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-X-ray-other-diagnostic-services.html'))
    x.append(getData('http://www.agrayellowpages.in/pin-clip-garments-pin.html'))
    x.append(getData('http://www.agrayellowpages.in/ice-cream-frozen-peas.html'))
    x.append(getData('http://www.agrayellowpages.in/cfl.html'))
    x.append(getData('http://www.agrayellowpages.in/railway-equipment-suppliers.html'))
#     121 to 130
    x.append(getData('http://www.agrayellowpages.in/machine-tools-manufacturers-distributors.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-doors.html'))
    x.append(getData('http://www.agrayellowpages.in/education-training-center.html'))
    x.append(getData('http://www.agrayellowpages.in/paper-manufacturers-distributors-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-homoeopathic-medicine-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/elastics-goods.html'))
    x.append(getData('http://www.agrayellowpages.in/blinds.html'))
    x.append(getData('http://www.agrayellowpages.in/hotels.html'))
    x.append(getData('http://www.agrayellowpages.in/jewellery-manufacturers-wholesalers.html'))
    x.append(getData('http://www.agrayellowpages.in/driving-school.html'))
#     131 to 140
    x.append(getData('http://www.agrayellowpages.in/plastic-blow-moulders.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-chest-specialists.html'))
    x.append(getData('http://www.agrayellowpages.in/yoga.html'))
    x.append(getData('http://www.agrayellowpages.in/steel-furniture.html'))
    x.append(getData('http://www.agrayellowpages.in/packaging-materials.html'))
    x.append(getData('http://www.agrayellowpages.in/restaurants-bars.html'))
    x.append(getData('http://www.agrayellowpages.in/ball-roller-bearing-bushes.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-products.html'))
    x.append(getData('http://www.agrayellowpages.in/welding-electrodes-equipments-cables.html'))
    x.append(getData('http://www.agrayellowpages.in/tyres-tubes-manufacturers-dealers.html'))
#     141 to 150
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/steel-furniture.html'))
    x.append(getData('http://www.agrayellowpages.in/fitness-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/engineering-equipment-material-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/pharmaceuticals-products-wholesalers-distributers.html'))
    x.append(getData('http://www.agrayellowpages.in/agricultural-pipes.html'))
    x.append(getData('http://www.agrayellowpages.in/video-recorders.html'))
    x.append(getData('http://www.agrayellowpages.in/plywood-timber-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/fitness-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/cold-storage.html'))
#     151 to 160
    x.append(getData('http://www.agrayellowpages.in/cloth-merchant.html'))
    x.append(getData('http://www.agrayellowpages.in/brass-products.html'))
    x.append(getData('http://www.agrayellowpages.in/water-treatments.html'))
    x.append(getData('http://www.agrayellowpages.in/brushes.html'))
    x.append(getData('http://www.agrayellowpages.in/printers-barcode.html'))
    x.append(getData('http://www.agrayellowpages.in/supari-merchant.html'))
    x.append(getData('http://www.agrayellowpages.in/barcode-printers.html'))
    x.append(getData('http://www.agrayellowpages.in/research-centres.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-exporters.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-surgeons.html'))
#     161 to 170
    x.append(getData('http://www.agrayellowpages.in/biological-apparatus.html'))
    x.append(getData('http://www.agrayellowpages.in/energy-saving-equipments.html'))
    x.append(getData('http://www.agrayellowpages.in/lamps.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-infertility-centre.html'))
    x.append(getData('http://www.agrayellowpages.in/stone-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/casting-ferrous-non-ferrous.html'))
    x.append(getData('http://www.agrayellowpages.in/flour-mills-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/battery-storage.html'))
    x.append(getData('http://www.agrayellowpages.in/cloth-merchant.html'))
    x.append(getData('http://www.agrayellowpages.in/dairy-products.html'))
#     171 t0 180
    x.append(getData('http://www.agrayellowpages.in/handicrafts-handlooms.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-cardiologists.html'))
    x.append(getData('http://www.agrayellowpages.in/doctor-gastro-enterologist.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-burn-unit.html'))
    x.append(getData('http://www.agrayellowpages.in/material-testing-lab.html'))
    x.append(getData('http://www.agrayellowpages.in/paper-manufacturers-distributors-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/sweet-farsan-shops-halwais.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-components.html'))
    x.append(getData('http://www.agrayellowpages.in/vaccume-equipment-systems.html'))
    x.append(getData('http://www.agrayellowpages.in/food-products.html'))
#     181 to 190
    x.append(getData('http://www.agrayellowpages.in/mementos.html'))
    x.append(getData('http://www.agrayellowpages.in/aluminium-utensils-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/fitness-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/architects.html'))
    x.append(getData('http://www.agrayellowpages.in/brass-products.html'))
    x.append(getData('http://www.agrayellowpages.in/#.html'))
    x.append(getData('http://www.agrayellowpages.in/wedding-cards.html'))
    x.append(getData('http://www.agrayellowpages.in/aluminium-partition.html'))
    x.append(getData('http://www.agrayellowpages.in/fitness-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/sports-goods-shoes.html'))
#     191 to 200
    x.append(getData('http://www.agrayellowpages.in/aluminium-door-window.html'))
    x.append(getData('http://www.agrayellowpages.in/biological-apparatus.html'))
    x.append(getData('http://www.agrayellowpages.in/pipes-tubes-fitting-plastics-pvc.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-cardiothorasic-vascules.html'))
    x.append(getData('http://www.agrayellowpages.in/barcode-printers.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-raw-materials.html'))
    x.append(getData('http://www.agrayellowpages.in/fitness-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/hand-pump.html'))
    x.append(getData('http://www.agrayellowpages.in/key-chains.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-endoscopy-laparoscopy.html'))
#     201 to 210
    x.append(getData('http://www.agrayellowpages.in/automobiles-manufactures-dealers.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-orthopedic.html'))
    x.append(getData('http://www.agrayellowpages.in/bicycle-manufacturers-dealers.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-psychiatrist-psychologists.html'))
    x.append(getData('http://www.agrayellowpages.in/diesel-engines-manfacturer-dealers.html'))
    x.append(getData('http://www.agrayellowpages.in/dairy-equipments-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/paper-manufacturers-distributors-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/marriage-bureau.html'))
    x.append(getData('http://www.agrayellowpages.in/mineral-water.html'))
#     211 to 220
    x.append(getData('http://www.agrayellowpages.in/doctor-tb-speicialist.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-machinery.html'))
    x.append(getData('http://www.agrayellowpages.in/printers-barcode.html'))
    x.append(getData('http://www.agrayellowpages.in/security-system-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/scientific-apparatus-instruments.html'))
    x.append(getData('http://www.agrayellowpages.in/surgical-appliances-equipment-supplies.html'))
    x.append(getData('http://www.agrayellowpages.in/sports-goods-shoes.html'))
    x.append(getData('http://www.agrayellowpages.in/transport-services.html'))
    x.append(getData('http://www.agrayellowpages.in/note-counting-machine.html'))
    x.append(getData('http://www.agrayellowpages.in/industrial-advisor.html'))
#     221 to 230
    x.append(getData('http://www.agrayellowpages.in/wire-wire-products.html'))
    x.append(getData('http://www.agrayellowpages.in/road-building-contractor.html'))
    x.append(getData('http://www.agrayellowpages.in/edible-oils-fats-refined.html'))
    x.append(getData('http://www.agrayellowpages.in/tiles-floorings-general.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-laproscopy.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-plastic-packaging.html'))
    x.append(getData('http://www.agrayellowpages.in/security-services.html'))
    x.append(getData('http://www.agrayellowpages.in/bakers-confectioneries-pastry-shops.html'))
    x.append(getData('http://www.agrayellowpages.in/medical-instruments.html'))
    x.append(getData('http://www.agrayellowpages.in/school-accessories.html'))
#     231 to 240
    x.append(getData('http://www.agrayellowpages.in/catering-plate.html'))
    x.append(getData('http://www.agrayellowpages.in/furniture-general.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-machinery.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-nutrition-obesity-clinic.html'))
    x.append(getData('http://www.agrayellowpages.in/sports-wear.html'))
    x.append(getData('http://www.agrayellowpages.in/ayurvedic-medicines.html'))
    x.append(getData('http://www.agrayellowpages.in/pharmaceuticals-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/mementos.html'))
    x.append(getData('http://www.agrayellowpages.in/voltage-stabilizers.html'))
#     241 to 250
    x.append(getData('http://www.agrayellowpages.in/industrial-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-foam.html'))
    x.append(getData('http://www.agrayellowpages.in/publishers-education-books.html'))
    x.append(getData('http://www.agrayellowpages.in/cleaning-products.html'))
    x.append(getData('http://www.agrayellowpages.in/ice-cream-frozen-desserts.html'))
    x.append(getData('http://www.agrayellowpages.in/commercial-kitchen-equipments.html'))
    x.append(getData('http://www.agrayellowpages.in/transport-services.html'))
    x.append(getData('http://www.agrayellowpages.in/welding-electrodes-equipments-cables.html'))
    x.append(getData('http://www.agrayellowpages.in/book-publishers-distributors-shops.html'))
    x.append(getData('http://www.agrayellowpages.in/water-level-controller.html'))
#     251 to 260
    x.append(getData('http://www.agrayellowpages.in/doctors-veterinary.html'))
    x.append(getData('http://www.agrayellowpages.in/machinery-parts-manufacturers-general.html'))
    x.append(getData('http://www.agrayellowpages.in/perforator-machinery-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/custom-clearing-agents.html'))
    x.append(getData('http://www.agrayellowpages.in/steel-furniture.html'))
    x.append(getData('http://www.agrayellowpages.in/fax-machines-services.html'))
    x.append(getData('http://www.agrayellowpages.in/agricultural-equipment-implements.html'))
    x.append(getData('http://www.agrayellowpages.in/surgical-appliances-equipment-supplies.html'))
    x.append(getData('http://www.agrayellowpages.in/vastu-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/kerosene-gas.html'))
#     261 to 270
    x.append(getData('http://www.agrayellowpages.in/homeopathic-medicines-stores.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-homoeopathic-medicine-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-products.html'))
    x.append(getData('http://www.agrayellowpages.in/invertors.html'))
    x.append(getData('http://www.agrayellowpages.in/medical-instruments.html'))
    x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
    x.append(getData('http://www.agrayellowpages.in/agricultural-equipment-implements.html'))
    x.append(getData('http://www.agrayellowpages.in/coaching-classes-language.html'))
    x.append(getData('http://www.agrayellowpages.in/musical-dance-classes.html'))
    x.append(getData('http://www.agrayellowpages.in/pharmaceuticals-products-wholesalers-distributers.html'))
#     271 to 280
    x.append(getData('http://www.agrayellowpages.in/ready-made-garments-manufacturers-dealers-retailers.html'))
    x.append(getData('http://www.agrayellowpages.in/swimming-pool.html'))
    x.append(getData('http://www.agrayellowpages.in/explosive-material.html'))
    x.append(getData('http://www.agrayellowpages.in/frozen-peas-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/corrugated-products.html'))
    x.append(getData('http://www.agrayellowpages.in/chemist-druggists.html'))
    x.append(getData('http://www.agrayellowpages.in/flour-mills-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/foreign-exchange.html'))
    x.append(getData('http://www.agrayellowpages.in/bathroom-fitting.html'))
    x.append(getData('http://www.agrayellowpages.in/boutiques.html'))
#     281 to 290
    x.append(getData('http://www.agrayellowpages.in/wireless-networking-solution.html'))
    x.append(getData('http://www.agrayellowpages.in/elastics-goods.html'))
    x.append(getData('http://www.agrayellowpages.in/packing-machine-manufacturer.html'))
    x.append(getData('http://www.agrayellowpages.in/share-brokers-consultants-otc-exchanges.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-critical-care.html'))
    x.append(getData('http://www.agrayellowpages.in/scientific-apparatus-instruments.html'))
    x.append(getData('http://www.agrayellowpages.in/automobiles-used-cars.html'))
    x.append(getData('http://www.agrayellowpages.in/industrial-belts.html'))
    x.append(getData('http://www.agrayellowpages.in/agricultural-inputs-fertilizers.html'))
    x.append(getData('http://www.agrayellowpages.in/consultants-computer.html'))
#     291 to 300
    x.append(getData('http://www.agrayellowpages.in/doctors-physiotherapists.html'))
    x.append(getData('http://www.agrayellowpages.in/air-conditioners-manufactures-dealers.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-cosmetic-surgeons.html'))
    x.append(getData('http://www.agrayellowpages.in/ball-roller-bearing-bushes.html'))
    x.append(getData('http://www.agrayellowpages.in/under-garments.html'))
    x.append(getData('http://www.agrayellowpages.in/mementos.html'))
    x.append(getData('http://www.agrayellowpages.in/engineering-equipment-material-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/leather-goods-accessories.html'))
    x.append(getData('http://www.agrayellowpages.in/automobile-air-Conditioning.html'))
    x.append(getData('http://www.agrayellowpages.in/sports-wear.html'))
#     301 to 310
    x.append(getData('http://www.agrayellowpages.in/food-machine-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/catering-caterers.html'))
    x.append(getData('http://www.agrayellowpages.in/utensils.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-doors.html'))
    x.append(getData('http://www.agrayellowpages.in/vaccume-equipment-systems.html'))
    x.append(getData('http://www.agrayellowpages.in/saree-shops-matching-centres.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-media-stationary-related-items.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-homoeopathic-medicine-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/chemical-construction.html'))
    x.append(getData('http://www.agrayellowpages.in/submersible-pump.html'))
#     311 to 320
    x.append(getData('http://www.agrayellowpages.in/security-system-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/office-automation-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-accessories.html'))
    x.append(getData('http://www.agrayellowpages.in/energy-saving-equipments.html'))
    x.append(getData('http://www.agrayellowpages.in/agri-tractors.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-plastic-packaging.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-hardware-peripherals.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-venereal-sexologists.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-pathologists.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-eye.html'))
#     321 to 330
    x.append(getData('http://www.agrayellowpages.in/shoe-soles.html'))
    x.append(getData('http://www.agrayellowpages.in/lights-lighting-products.html'))
    x.append(getData('http://www.agrayellowpages.in/swimming-pool.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-safety-Industrial.html'))
    x.append(getData('http://www.agrayellowpages.in/interior-decorators-designers.html'))
    x.append(getData('http://www.agrayellowpages.in/water-purifiers.html'))
    x.append(getData('http://www.agrayellowpages.in/shoe-welts.html'))
    x.append(getData('http://www.agrayellowpages.in/salt-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/construction-equipments.html'))
    x.append(getData('http://www.agrayellowpages.in/house-keeping.html'))
#     331 to 340
    x.append(getData('http://www.agrayellowpages.in/doctors-joint-replacement.html'))
    x.append(getData('http://www.agrayellowpages.in/Doctors-Dentists.html'))
    x.append(getData('http://www.agrayellowpages.in/interior-decorators-designers.html'))
    x.append(getData('http://www.agrayellowpages.in/tour-travel.html'))
    x.append(getData('http://www.agrayellowpages.in/telebrand-shopping.html'))
    x.append(getData('http://www.agrayellowpages.in/shoe-exporters.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-skin-dermatologists.html'))
    x.append(getData('http://www.agrayellowpages.in/dairy-products.html'))
    x.append(getData('http://www.agrayellowpages.in/food-machine-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/brushes.html'))
#     341 to 350
    x.append(getData('http://www.agrayellowpages.in/doctors-allergy.html'))
    x.append(getData('http://www.agrayellowpages.in/chemicals-industrial-general.html'))
    x.append(getData('http://www.agrayellowpages.in/lubricating-oils-greases.html'))
    x.append(getData('http://www.agrayellowpages.in/aluminium-partition.html'))
    x.append(getData('http://www.agrayellowpages.in/ups.html'))
    x.append(getData('http://www.agrayellowpages.in/battery-storage.html'))
    x.append(getData('http://www.agrayellowpages.in/placement-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-software-services.html'))
    x.append(getData('http://www.agrayellowpages.in/food-processing-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/gifts-novelties.html'))
#     351 to 360
    x.append(getData('http://www.agrayellowpages.in/paper-manufacturers-distributors-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/automobiles-gas-kit.html'))
    x.append(getData('http://www.agrayellowpages.in/tyre-retreading-repairs.html'))
    x.append(getData('http://www.agrayellowpages.in/welding-electrodes-equipments-cables.html'))
    x.append(getData('http://www.agrayellowpages.in/explosive-material.html'))
    x.append(getData('http://www.agrayellowpages.in/diagnostics-equipments-distributors.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-machinery.html'))
    x.append(getData('http://www.agrayellowpages.in/security-system-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/powder-coating.html'))
    x.append(getData('http://www.agrayellowpages.in/guest-house.html'))
#     361 to 370
    x.append(getData('http://www.agrayellowpages.in/ventian-blinds.html'))
    x.append(getData('http://www.agrayellowpages.in/medals.html'))
    x.append(getData('http://www.agrayellowpages.in/supari-merchant.html'))
    x.append(getData('http://www.agrayellowpages.in/sweet-farsan-shops-halwais.html'))
    x.append(getData('http://www.agrayellowpages.in/electronic-goods-show-rooms.html'))
    x.append(getData('http://www.agrayellowpages.in/furniture-general.html'))
    x.append(getData('http://www.agrayellowpages.in/banquets-halls-caterers.html'))
    x.append(getData('http://www.agrayellowpages.in/ball-roller-bearing-bushes.html'))
    x.append(getData('http://www.agrayellowpages.in/ball-roller-bearing-bushes.html'))
    x.append(getData('http://www.agrayellowpages.in/electrical-goods-service-repairs.html'))
#     371 to 380
    x.append(getData('http://www.agrayellowpages.in/voltage-stabilizers.html'))
    x.append(getData('http://www.agrayellowpages.in/interior-decorators-designers.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-training.html'))
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/generators-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/tiles-floorings-general.html'))
    x.append(getData('http://www.agrayellowpages.in/construction-equipments.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-training.html'))
    x.append(getData('http://www.agrayellowpages.in/ice-cream-suppliers-distributors.html'))
    x.append(getData('http://www.agrayellowpages.in/generators-spares-parts-suppliers-repairs.html'))
#     381 to 390
    x.append(getData('http://www.agrayellowpages.in/radiators.html'))
    x.append(getData('http://www.agrayellowpages.in/sport-complex.html'))
    x.append(getData('http://www.agrayellowpages.in/security-system-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/stationery-general.html'))
    x.append(getData('http://www.agrayellowpages.in/pin-clip-garments-pin.html'))
    x.append(getData('http://www.agrayellowpages.in/glass-gifts-items.html'))
    x.append(getData('http://www.agrayellowpages.in/property-real-estate.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-injuction-moulders.html'))
    x.append(getData('http://www.agrayellowpages.in/tube-boring-wells.html'))
    x.append(getData('http://www.agrayellowpages.in/landscape-environment-horticulturist.html'))
#     391 to 400
    x.append(getData('http://www.agrayellowpages.in/paper-manufacturer-convertor.html'))
    x.append(getData('http://www.agrayellowpages.in/home-appliances.html'))
    x.append(getData('http://www.agrayellowpages.in/health-club-equipments.html'))
    x.append(getData('http://www.agrayellowpages.in/glass-beads.html'))
    x.append(getData('http://www.agrayellowpages.in/laces-threads.html'))
    x.append(getData('http://www.agrayellowpages.in/generators-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/water-purifiers.html'))
    x.append(getData('http://www.agrayellowpages.in/pharmaceuticals-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/jewellery-machines-tools.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-granules.html'))
#     401 to 410
    x.append(getData('http://www.agrayellowpages.in/landscape-environment-horticulturist.html'))
    x.append(getData('http://www.agrayellowpages.in/printers-general.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-pediatricians.html'))
    x.append(getData('http://www.agrayellowpages.in/sanitaryware-manufacturers-dealers.html'))
    x.append(getData('http://www.agrayellowpages.in/doctor-acupuncture.html'))
    x.append(getData('http://www.agrayellowpages.in/ready-made-garments-manufacturers-dealers-retailers.html'))
    x.append(getData('http://www.agrayellowpages.in/aluminium-door-window.html'))
    x.append(getData('http://www.agrayellowpages.in/jewellery-machines-tools.html'))
    x.append(getData('http://www.agrayellowpages.in/exporters-leather-goods-shoes.html'))
    x.append(getData('http://www.agrayellowpages.in/sweet-farsan-shops-halwais.html'))
#     411 to 420
    x.append(getData('http://www.agrayellowpages.in/colour-manufacturer.html'))
    x.append(getData('http://www.agrayellowpages.in/kirana-spices-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/metal-perforators.html'))
    x.append(getData('http://www.agrayellowpages.in/HR-consultants.html'))
    x.append(getData('http://www.agrayellowpages.in/elevator-contractors-suppliers-maintainence.html'))
    x.append(getData('http://www.agrayellowpages.in/ups.html'))
    x.append(getData('http://www.agrayellowpages.in/bakers-confectioneries-pastry-shops.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-machinery.html'))
    x.append(getData('http://www.agrayellowpages.in/brass-products.html'))
    x.append(getData('http://www.agrayellowpages.in/coaching-classes-cookery.html'))
#     421 to 430
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/sports-goods-shoes.html'))
    x.append(getData('http://www.agrayellowpages.in/bottles.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-consultant-physicians.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-design.html'))
    x.append(getData('http://www.agrayellowpages.in/electro-galvanising-anodising.html'))
    x.append(getData('http://www.agrayellowpages.in/ups.html'))
    x.append(getData('http://www.agrayellowpages.in/diagnostics-equipments-distributors.html'))
    x.append(getData('http://www.agrayellowpages.in/piston-piston-rings.html'))
    x.append(getData('http://www.agrayellowpages.in/electric-goods.html'))
#     431 to 440
    x.append(getData('http://www.agrayellowpages.in/powder-coating.html'))
    x.append(getData('http://www.agrayellowpages.in/play-group-school.html'))
    x.append(getData('http://www.agrayellowpages.in/packaging-materials.html'))
    x.append(getData('http://www.agrayellowpages.in/leather-goods-accessories.html'))
    x.append(getData('http://www.agrayellowpages.in/gifts-novelties.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-gynecologists-obstetricians.html'))
    x.append(getData('http://www.agrayellowpages.in/pop-interior-works.html'))
    x.append(getData('http://www.agrayellowpages.in/trophys-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-components-shoe-last.html'))
    x.append(getData('http://www.agrayellowpages.in/energy-saving-equipments.html'))
#     441 to 450
    x.append(getData('http://www.agrayellowpages.in/catering-caterers.html'))
    x.append(getData('http://www.agrayellowpages.in/nigros-diesel.html'))
    x.append(getData('http://www.agrayellowpages.in/paints.html'))
    x.append(getData('http://www.agrayellowpages.in/flex-printing-vinyl-printing.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-oncology.html'))
    x.append(getData('http://www.agrayellowpages.in/biotechnology.html'))
    x.append(getData('http://www.agrayellowpages.in/steel-furniture.html'))
    x.append(getData('http://www.agrayellowpages.in/chemist-druggists.html'))
    x.append(getData('http://www.agrayellowpages.in/battery-storage.html'))
    x.append(getData('http://www.agrayellowpages.in/fire-protection-equipment-suppliers.html'))
#     451 to 460
    x.append(getData('http://www.agrayellowpages.in/health-slimming-centre.html'))
    x.append(getData('http://www.agrayellowpages.in/furnishing-material-furnishers.html'))
    x.append(getData('http://www.agrayellowpages.in/mineral-water.html'))
    x.append(getData('http://www.agrayellowpages.in/fax-machines-services.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-welts.html'))
    x.append(getData('http://www.agrayellowpages.in/transformers.html'))
    x.append(getData('http://www.agrayellowpages.in/ice-cream-frozen-desserts.html'))
    x.append(getData('http://www.agrayellowpages.in/aluminium-partition.html'))
    x.append(getData('http://www.agrayellowpages.in/jewellery-immitation.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-ivf-centre.html'))
#     461 to 470
    x.append(getData('http://www.agrayellowpages.in/homeopathic-medicines-stores.html'))
    x.append(getData('http://www.agrayellowpages.in/stationery-general.html'))
    x.append(getData('http://www.agrayellowpages.in/packing-machine-manufacturer.html'))
    x.append(getData('http://www.agrayellowpages.in/cast-iron-pipes-fitting.html'))
    x.append(getData('http://www.agrayellowpages.in/paper-manufacturer-convertor.html'))
    x.append(getData('http://www.agrayellowpages.in/.html'))
    x.append(getData('http://www.agrayellowpages.in/packing-machine-manufacturer.html'))
    x.append(getData('http://www.agrayellowpages.in/elevator-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-products.html'))
    x.append(getData('http://www.agrayellowpages.in/footwear-manufacturer-wolesalers-traders.html'))
#     471 to 480
    x.append(getData('http://www.agrayellowpages.in/doctors-dermatologist.html'))
    x.append(getData('http://www.agrayellowpages.in/tube-boring-wells.html'))
    x.append(getData('http://www.agrayellowpages.in/electronic-goods-show-rooms.html'))
    x.append(getData('http://www.agrayellowpages.in/automobiles-accessories.html'))
    x.append(getData('http://www.agrayellowpages.in/kirana-spices-merchants.html'))
    x.append(getData('http://www.agrayellowpages.in/electro-plating.html'))
    x.append(getData('http://www.agrayellowpages.in/diesel-engines-spares-manufacturers-dealers.html'))
    x.append(getData('http://www.agrayellowpages.in/builders-building-contractors.html'))
    x.append(getData('http://www.agrayellowpages.in/cartridge-refilling.html'))
    x.append(getData('http://www.agrayellowpages.in/automobiles-manufactures-dealers.html'))
#     481 to 490
    x.append(getData('http://www.agrayellowpages.in/refrigerators-freezers-manufacturers-dealer.html'))
    x.append(getData('http://www.agrayellowpages.in/building-material-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/doctor-ultrasound.html'))
    x.append(getData('http://www.agrayellowpages.in/diagnostics-equipments-distributors.html'))
    x.append(getData('http://www.agrayellowpages.in/office-automation-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/thread-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/furnishing-material-furnishers.html'))
    x.append(getData('http://www.agrayellowpages.in/shoe-lining-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/air-cooling.html'))
    x.append(getData('http://www.agrayellowpages.in/jewellery-showrooms-retailers.html'))
#     491 to 500
    x.append(getData('http://www.agrayellowpages.in/tele-communication-systems-equp-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/automobiles-garages-service-centre.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-hand-surgeon-micro-surgeons.html'))
    x.append(getData('http://www.agrayellowpages.in/pathology-laboratories-eqiupments-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/generators-service-repair.html'))
    x.append(getData('http://www.agrayellowpages.in/chains-imitation.html'))
    x.append(getData('http://www.agrayellowpages.in/generators-silent-canopy.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-education.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-cancer-physician.html'))
    x.append(getData('http://www.agrayellowpages.in/computer-education.html'))
#     501 to 510
    x.append(getData('http://www.agrayellowpages.in/plastic-products.html'))
    x.append(getData('http://www.agrayellowpages.in/pathology-laboratories-eqiupments-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/bangles-shop-mfrs-distributor.html'))
    x.append(getData('http://www.agrayellowpages.in/shoe-manufacturer-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/hankies.html'))
    x.append(getData('http://www.agrayellowpages.in/shoe-chemicals.html'))
    x.append(getData('http://www.agrayellowpages.in/tea-retailers-wholesalers.html'))
    x.append(getData('http://www.agrayellowpages.in/CCTV.html'))
    x.append(getData('http://www.agrayellowpages.in/plastic-doors.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-echo-cardiologist.html'))
#     511 to 520
    x.append(getData('http://www.agrayellowpages.in/photocopying-machines-sale-service.html'))
    x.append(getData('http://www.agrayellowpages.in/oil-processing-equipment.html'))
    x.append(getData('http://www.agrayellowpages.in/floor-coverings.html'))
    x.append(getData('http://www.agrayellowpages.in/sport-complex.html'))
    x.append(getData('http://www.agrayellowpages.in/exporters-leather-goods-shoes.html'))
    x.append(getData('http://www.agrayellowpages.in/dairy-equipments-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/jewellery-immitation.html'))
    x.append(getData('http://www.agrayellowpages.in/tube-boring-wells.html'))
    x.append(getData('http://www.agrayellowpages.in/transformers.html'))
    x.append(getData('http://www.agrayellowpages.in/hospitals-nursing-home.html'))
#     521 to 530
    x.append(getData('http://www.agrayellowpages.in/doctor-retina-specialist.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-menopause.html'))
    x.append(getData('http://www.agrayellowpages.in/frozen-peas-manufacturers.html'))
    x.append(getData('http://www.agrayellowpages.in/lights-lighting-products.html'))
    x.append(getData('http://www.agrayellowpages.in/tele-communication-systems-equp-manufacturers-suppliers.html'))
    x.append(getData('http://www.agrayellowpages.in/pattern-maker.html'))
    x.append(getData('http://www.agrayellowpages.in/doctors-diabetologists.html'))
    x.append(getData('http://www.agrayellowpages.in/security-services.html'))
#     x.append(getData(''))
#     x.append(getData(''))
#     531 to 538


#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
    
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))

#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))
#     x.append(getData(''))


    

    from functools import reduce
    single_list = reduce(lambda x,y: x+y, x)
    print(single_list)
    for row_num, data in enumerate(single_list):
        worksheet1.write(row_num, 0, data)
    
    workbook.close()
    
getMobile()

# getMobile('http://www.agrayellowpages.in/agricultural-cf-agents.html')
# Out:
# ['+91-9457061201', '+91-9012200152', '+91-7409176919', '+91-9412723847', '+91-9412160472', '+91-9411684686', '+91-9917675740', '+91-9452693496', '+91-9837426423', '+91-9719818555', '+91-9410876088', '+91-9557860759', '+91-9837147725', '+91-98970-1152', '+91-9837015806', '+91-9837321998', '+91-562-329852', '+91-9760477283', '+91-9983717694', '+91-9719132200', '+91-9058141145', '+91-9258377061', '+91-', '+91-9412722187', '+91-9359050766', '+91-97580 6456', '+91-9319104658', '+91-9917172172', '+91-9319104658', '+91-9997151830', '+91-9319103759', '+91-9219443402', '+91-9837014128', '+91-9412059357', '+91-9837272649', '+91-9412056952', '+91-9412155584', '+91-9837766670', '+91-94102 5231', '+91-9412010673', '+91-9412262366', '+91-9412160638', '+91-9837073046', '+91-9897115028', '+91-9897222714', '+91-9997092423', '+91-9634019045', '+91-9358398610', '+91-9837039958', '+91-9760010487', '+91-9897530265', '+91-9259308318', '+91-9411964413', '+91-9927086336', '+91-562-400774', '+91-7351225511',
# ...
